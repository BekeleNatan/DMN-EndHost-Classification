# %%
# %load_ext autoreload
# %autoreload 2
from ProfileBuilder import Graphlet
import networkx as nx
import matplotlib.pyplot as plt
from sklearn import svm, datasets

from networkx.drawing.nx_pylab import draw_kamada_kawai, draw_spring
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
graphlet = Graphlet('data/paper.csv')

# %%
X = graphlet.activity_graphlets
y = graphlet.get_graphlets_label()

# %%
profile_graphlets = graphlet.profile_graphlets

# %%
# plot


draw_kamada_kawai(profile_graphlets[0], with_labels= True, alpha = 0.5, node_size= 500)
plt.show()
